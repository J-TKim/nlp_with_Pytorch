# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** .5), -1)
    
    plt.imshow(x, cmap="gray")
    plt.show()

# %%
from argparse import Namespace

config = {
    "train_ratio": .8,
    "batch_size": 256,
    "n_epochs": 50,
    "verbose": 1,
    "btl_size": 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_x = train_x
train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)
train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
train_x = train_x.to("cuda")
valid_x = valid_x.to("cuda")
test_x = test_x.to("cuda")

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size).to("cuda")
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=5.5909e-02  valid_loss=4.3475e-02  lowest_loss=4.3475e-02
# Epoch(2/50): train_loss=4.3124e-02  valid_loss=4.1413e-02  lowest_loss=4.1413e-02
# Epoch(3/50): train_loss=4.1370e-02  valid_loss=4.0039e-02  lowest_loss=4.0039e-02
# Epoch(4/50): train_loss=4.0631e-02  valid_loss=3.9750e-02  lowest_loss=3.9750e-02
# Epoch(5/50): train_loss=4.0169e-02  valid_loss=3.9106e-02  lowest_loss=3.9106e-02
# Epoch(6/50): train_loss=3.9608e-02  valid_loss=3.8787e-02  lowest_loss=3.8787e-02
# Epoch(7/50): train_loss=3.9285e-02  valid_loss=3.7739e-02  lowest_loss=3.7739e-02
# Epoch(8/50): train_loss=3.9106e-02  valid_loss=3.7828e-02  lowest_loss=3.7739e-02
# Epoch(9/50): train_loss=3.8812e-02  valid_loss=3.7608e-02  lowest_loss=3.7608e-02
# Epoch(10/50): train_loss=3.8911e-02  valid_loss=3.8016e-02  lowest_loss=3.7608e-02
# Epoch(11/50): train_loss=3.8712e-02  valid_loss=3.7810e-02  lowest_loss=3.7608e-02
# Epoch(12/50): train_loss=3.8200e-02  valid_loss=3.6926e-02  lowest_loss=3.6926e-02
# Epoch(13/50): train_loss=3.8202e-02  valid_loss=3.7220e-02  lowest_loss=3.6926e-02
# Epoch(14/50): train_loss=3.8091e-02  valid_loss=3.6613e-02  lowest_loss=3.6613e-02
# Epoch(15/50): train_loss=3.7675e-02  valid_loss=3.6938e-02  lowest_loss=3.6613e-02
# Epoch(16/50): train_loss=3.7740e-02  valid_loss=3.6661e-02  lowest_loss=3.6613e-02
# Epoch(17/50): train_loss=3.7601e-02  valid_loss=3.6565e-02  lowest_loss=3.6565e-02
# Epoch(18/50): train_loss=3.7467e-02  valid_loss=3.6572e-02  lowest_loss=3.6565e-02
# Epoch(19/50): train_loss=3.7381e-02  valid_loss=3.5905e-02  lowest_loss=3.5905e-02
# Epoch(20/50): train_loss=3.7037e-02  valid_loss=3.6338e-02  lowest_loss=3.5905e-02
# Epoch(21/50): train_loss=3.7301e-02  valid_loss=3.5887e-02  lowest_loss=3.5887e-02
# Epoch(22/50): train_loss=3.7054e-02  valid_loss=3.5900e-02  lowest_loss=3.5887e-02
# Epoch(23/50): train_loss=3.6942e-02  valid_loss=3.5800e-02  lowest_loss=3.5800e-02
# Epoch(24/50): train_loss=3.7381e-02  valid_loss=3.7098e-02  lowest_loss=3.5800e-02
# Epoch(25/50): train_loss=3.7880e-02  valid_loss=3.6107e-02  lowest_loss=3.5800e-02
# Epoch(26/50): train_loss=3.7236e-02  valid_loss=3.6495e-02  lowest_loss=3.5800e-02
# Epoch(27/50): train_loss=3.7052e-02  valid_loss=3.6540e-02  lowest_loss=3.5800e-02
# Epoch(28/50): train_loss=3.7044e-02  valid_loss=3.6000e-02  lowest_loss=3.5800e-02
# Epoch(29/50): train_loss=3.6903e-02  valid_loss=3.6365e-02  lowest_loss=3.5800e-02
# Epoch(30/50): train_loss=3.7025e-02  valid_loss=3.5955e-02  lowest_loss=3.5800e-02
# Epoch(31/50): train_loss=3.6742e-02  valid_loss=3.5416e-02  lowest_loss=3.5416e-02
# Epoch(32/50): train_loss=3.6481e-02  valid_loss=3.5623e-02  lowest_loss=3.5416e-02
# Epoch(33/50): train_loss=3.6673e-02  valid_loss=3.5908e-02  lowest_loss=3.5416e-02
# Epoch(34/50): train_loss=3.6415e-02  valid_loss=3.5341e-02  lowest_loss=3.5341e-02
# Epoch(35/50): train_loss=3.6324e-02  valid_loss=3.5382e-02  lowest_loss=3.5341e-02
# Epoch(36/50): train_loss=3.6260e-02  valid_loss=3.5250e-02  lowest_loss=3.5250e-02
# Epoch(37/50): train_loss=3.6178e-02  valid_loss=3.5225e-02  lowest_loss=3.5225e-02
# Epoch(38/50): train_loss=3.5997e-02  valid_loss=3.4771e-02  lowest_loss=3.4771e-02
# Epoch(39/50): train_loss=3.6075e-02  valid_loss=3.5585e-02  lowest_loss=3.4771e-02
# Epoch(40/50): train_loss=3.6264e-02  valid_loss=3.5067e-02  lowest_loss=3.4771e-02
# Epoch(41/50): train_loss=3.5928e-02  valid_loss=3.4574e-02  lowest_loss=3.4574e-02
# Epoch(42/50): train_loss=3.5669e-02  valid_loss=3.5242e-02  lowest_loss=3.4574e-02
# Epoch(43/50): train_loss=3.5744e-02  valid_loss=3.4479e-02  lowest_loss=3.4479e-02
# Epoch(44/50): train_loss=3.5890e-02  valid_loss=3.5456e-02  lowest_loss=3.4479e-02
# Epoch(45/50): train_loss=3.5658e-02  valid_loss=3.4887e-02  lowest_loss=3.4479e-02
# Epoch(46/50): train_loss=3.5619e-02  valid_loss=3.4484e-02  lowest_loss=3.4479e-02
# Epoch(47/50): train_loss=3.5460e-02  valid_loss=3.4987e-02  lowest_loss=3.4479e-02
# Epoch(48/50): train_loss=3.5533e-02  valid_loss=3.4686e-02  lowest_loss=3.4479e-02
# Epoch(49/50): train_loss=3.5519e-02  valid_loss=3.4792e-02  lowest_loss=3.4479e-02
# Epoch(50/50): train_loss=3.5613e-02  valid_loss=3.4843e-02  lowest_loss=3.4479e-02

# %% [markdown]
# ## Mean value in each space

# %%
with torch.no_grad():
    import random
    
    index1 = int(random.random() * test_x.size(0))
    index2 = int(random.random() * test_x.size(0))
    
    z1 = model.encoder(test_x[index1].view(1, -1))
    z2 = model.encoder(test_x[index2].view(1, -1))
    
    recon = model.decoder((z1 + z2) / 2).squeeze()
    
    show_image(test_x[index1])
    show_image(test_x[index2])
    show_image((test_x[index1] + test_x[index2] / 2))
    show_image(recon)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ada2442a45df> in <module>
#      10     recon = model.decoder((z1 + z2) / 2).squeeze()
#      11
# ---> 12     show_image(test_x[index1])
#      13     show_image(test_x[index2])
#      14     show_image((test_x[index1] + test_x[index2] / 2))
#
# <ipython-input-4-c40c3c934820> in show_image(x)
#       3         x = x.view(int(x.size(0) ** .5), -1)
#       4
# ----> 5     plt.imshow(x, cmap="gray")
#       6     plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5613                               resample=resample, **kwargs)
#    5614
# -> 5615         im.set_data(X)
#    5616         im.set_alpha(alpha)
#    5617         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in set_data(self, A)
#     687             if isinstance(A, Image.Image):
#     688                 A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 689         self._A = cbook.safe_masked_invalid(A, copy=True)
#     690
#     691         if (self._A.dtype != np.uint8 and
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#     704
#     705 def safe_masked_invalid(x, copy=False):
# --> 706     x = np.array(x, subok=True, copy=copy)
#     707     if not x.dtype.isnative:
#     708         # Note that the argument to `byteswap` is 'inplace',
#
# ~/.venv/torch1.4.0-py3.6-cuda10.1/lib/python3.6/site-packages/torch/tensor.py in __array__(self, dtype)
#     484     def __array__(self, dtype=None):
#     485         if dtype is None:
# --> 486             return self.numpy()
#     487         else:
#     488             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert CUDA tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
