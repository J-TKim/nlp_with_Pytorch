# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** .5), -1)
    
    plt.imshow(x, cmap="gray")
    plt.show()

# %%
from argparse import Namespace

config = {
    "train_ratio": .8,
    "batch_size": 256,
    "n_epochs": 50,
    "verbose": 1,
    "btl_size": 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_x = train_x
train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)
train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
train_x = train_x.to("cuda")
valid_x = valid_x.to("cuda")
test_x = test_x.to("cuda")

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size).to("cuda")
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=5.5561e-02  valid_loss=4.5248e-02  lowest_loss=4.5248e-02
# Epoch(2/50): train_loss=4.3900e-02  valid_loss=4.2286e-02  lowest_loss=4.2286e-02
# Epoch(3/50): train_loss=4.2400e-02  valid_loss=4.1706e-02  lowest_loss=4.1706e-02
# Epoch(4/50): train_loss=4.1437e-02  valid_loss=3.9995e-02  lowest_loss=3.9995e-02
# Epoch(5/50): train_loss=4.0591e-02  valid_loss=3.9847e-02  lowest_loss=3.9847e-02
# Epoch(6/50): train_loss=4.0241e-02  valid_loss=3.9817e-02  lowest_loss=3.9817e-02
# Epoch(7/50): train_loss=3.9659e-02  valid_loss=3.9160e-02  lowest_loss=3.9160e-02
# Epoch(8/50): train_loss=3.9588e-02  valid_loss=3.8920e-02  lowest_loss=3.8920e-02
# Epoch(9/50): train_loss=3.9546e-02  valid_loss=3.9252e-02  lowest_loss=3.8920e-02
# Epoch(10/50): train_loss=3.9171e-02  valid_loss=3.8178e-02  lowest_loss=3.8178e-02
# Epoch(11/50): train_loss=3.9055e-02  valid_loss=3.8973e-02  lowest_loss=3.8178e-02
# Epoch(12/50): train_loss=3.8804e-02  valid_loss=3.8728e-02  lowest_loss=3.8178e-02
# Epoch(13/50): train_loss=3.8426e-02  valid_loss=3.7873e-02  lowest_loss=3.7873e-02
# Epoch(14/50): train_loss=3.8709e-02  valid_loss=3.7966e-02  lowest_loss=3.7873e-02
# Epoch(15/50): train_loss=3.8524e-02  valid_loss=3.7776e-02  lowest_loss=3.7776e-02
# Epoch(16/50): train_loss=3.8220e-02  valid_loss=3.7989e-02  lowest_loss=3.7776e-02
# Epoch(17/50): train_loss=3.8503e-02  valid_loss=3.7752e-02  lowest_loss=3.7752e-02
# Epoch(18/50): train_loss=3.8301e-02  valid_loss=3.7382e-02  lowest_loss=3.7382e-02
# Epoch(19/50): train_loss=3.8243e-02  valid_loss=3.7424e-02  lowest_loss=3.7382e-02
# Epoch(20/50): train_loss=3.7981e-02  valid_loss=3.7049e-02  lowest_loss=3.7049e-02
# Epoch(21/50): train_loss=3.7753e-02  valid_loss=3.7164e-02  lowest_loss=3.7049e-02
# Epoch(22/50): train_loss=3.7666e-02  valid_loss=3.6922e-02  lowest_loss=3.6922e-02
# Epoch(23/50): train_loss=3.7612e-02  valid_loss=3.7395e-02  lowest_loss=3.6922e-02
# Epoch(24/50): train_loss=3.7769e-02  valid_loss=3.6803e-02  lowest_loss=3.6803e-02
# Epoch(25/50): train_loss=3.7599e-02  valid_loss=3.6683e-02  lowest_loss=3.6683e-02
# Epoch(26/50): train_loss=3.7355e-02  valid_loss=3.6956e-02  lowest_loss=3.6683e-02
# Epoch(27/50): train_loss=3.7287e-02  valid_loss=3.6633e-02  lowest_loss=3.6633e-02
# Epoch(28/50): train_loss=3.7650e-02  valid_loss=3.6296e-02  lowest_loss=3.6296e-02
# Epoch(29/50): train_loss=3.7205e-02  valid_loss=3.6350e-02  lowest_loss=3.6296e-02
# Epoch(30/50): train_loss=3.7032e-02  valid_loss=3.6361e-02  lowest_loss=3.6296e-02
# Epoch(31/50): train_loss=3.7092e-02  valid_loss=3.7794e-02  lowest_loss=3.6296e-02
# Epoch(32/50): train_loss=3.7066e-02  valid_loss=3.6307e-02  lowest_loss=3.6296e-02
# Epoch(33/50): train_loss=3.6924e-02  valid_loss=3.6673e-02  lowest_loss=3.6296e-02
# Epoch(34/50): train_loss=3.7073e-02  valid_loss=3.6924e-02  lowest_loss=3.6296e-02
# Epoch(35/50): train_loss=3.7084e-02  valid_loss=3.6531e-02  lowest_loss=3.6296e-02
# Epoch(36/50): train_loss=3.7040e-02  valid_loss=3.6558e-02  lowest_loss=3.6296e-02
# Epoch(37/50): train_loss=3.6911e-02  valid_loss=3.6299e-02  lowest_loss=3.6296e-02
# Epoch(38/50): train_loss=3.6816e-02  valid_loss=3.6235e-02  lowest_loss=3.6235e-02
# Epoch(39/50): train_loss=3.6467e-02  valid_loss=3.6176e-02  lowest_loss=3.6176e-02
# Epoch(40/50): train_loss=3.6341e-02  valid_loss=3.6144e-02  lowest_loss=3.6144e-02
# Epoch(41/50): train_loss=3.6672e-02  valid_loss=3.6322e-02  lowest_loss=3.6144e-02
# Epoch(42/50): train_loss=3.7116e-02  valid_loss=3.6672e-02  lowest_loss=3.6144e-02
# Epoch(43/50): train_loss=3.7480e-02  valid_loss=3.6657e-02  lowest_loss=3.6144e-02
# Epoch(44/50): train_loss=3.6888e-02  valid_loss=3.6351e-02  lowest_loss=3.6144e-02
# Epoch(45/50): train_loss=3.6908e-02  valid_loss=3.6142e-02  lowest_loss=3.6142e-02
# Epoch(46/50): train_loss=3.7073e-02  valid_loss=3.6551e-02  lowest_loss=3.6142e-02
# Epoch(47/50): train_loss=3.6975e-02  valid_loss=3.6294e-02  lowest_loss=3.6142e-02
# Epoch(48/50): train_loss=3.6666e-02  valid_loss=3.6128e-02  lowest_loss=3.6128e-02
# Epoch(49/50): train_loss=3.6455e-02  valid_loss=3.5695e-02  lowest_loss=3.5695e-02
# Epoch(50/50): train_loss=3.6407e-02  valid_loss=3.5992e-02  lowest_loss=3.5695e-02

# %% [markdown]
# ## Mean value in each space

# %%
with torch.no_grad():
    import random
    
    index1 = int(random.random() * test_x.size(0))
    index2 = int(random.random() * test_x.size(0))
    
    z1 = model.encoder(test_x[index1].view(1, -1))
    z2 = model.encoder(test_x[index2].view(1, -1))
    
    recon = model.decoder((z1 + z2) / 2).squeeze()
    
    show_image(test_x[index1])
    show_image(test_x[index2])
    show_image((test_x[index1] + test_x[index2] / 2))
    show_image(recon)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-4d75ff1c6dce> in <module>
#       6
#       7     model = model.to("cpu")
# ----> 8     z1 = model.encoder(test_x[index1].view(1, -1))
#       9     z2 = model.encoder(test_x[index2].view(1, -1))
#      10
#
# ~/.venv/torch1.4.0-py3.6-cuda10.1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.venv/torch1.4.0-py3.6-cuda10.1/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/.venv/torch1.4.0-py3.6-cuda10.1/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.venv/torch1.4.0-py3.6-cuda10.1/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/.venv/torch1.4.0-py3.6-cuda10.1/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# RuntimeError: Expected object of device type cuda but got device type cpu for argument #1 'self' in call to _th_addmm
