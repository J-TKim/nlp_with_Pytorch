# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from utils import load_mnist
from trainer import Trainer

# %%
from argparse import Namespace

config = {
    "train_ratio": .8,
    "batch_size": 256,
    "n_epochs": 50,
    "verbose": 1,
    "btl_size": 2
}

config = Namespace(**config)

print(config)
# Out:
# Namespace(batch_size=256, btl_size=2, n_epochs=50, train_ratio=0.8, verbose=1)

# %%
def show_image(x):
    if x.dim() == 1:
        x = x.view(int(x.size(0) ** .5), -1)
        
    plt.imshow(x, cmap="gray")
    plt.show()

# %%
train_x, train_y = load_mnist(flatten=True)
test_x, test_y = load_mnist(is_train=False, flatten=True)

train_cnt = int(train_x.size(0) * config.train_ratio)
valid_cnt = train_x.size(0) - train_cnt

# Shuffle dataset to split into train/valid set.
indices = torch.randperm(train_x.size(0))
train_x, valid_x = torch.index_select(
    train_x,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

train_y, valid_y = torch.index_select(
    train_y,
    dim=0,
    index=indices
).split([train_cnt, valid_cnt], dim=0)

print("Train:", train_x.shape, train_y.shape)
print("Valid:", valid_x.shape, valid_y.shape)
print("Test:", test_x.shape, test_y.shape)
# Out:
# Train: torch.Size([48000, 784]) torch.Size([48000])
# Valid: torch.Size([12000, 784]) torch.Size([12000])
# Test: torch.Size([10000, 784]) torch.Size([10000])

# %%
from model import Autoencoder

# %%
model = Autoencoder(btl_size=config.btl_size)
optimizer = optim.Adam(model.parameters())
crit = nn.MSELoss()

trainer = Trainer(model, optimizer, crit)

# %%
trainer.train((train_x, train_x), (valid_x, valid_x), config)
# Out:
# Epoch(1/50): train_loss=5.7922e-02  valid_loss=4.5650e-02  lowest_loss=4.5650e-02
# Epoch(2/50): train_loss=4.4248e-02  valid_loss=4.2321e-02  lowest_loss=4.2321e-02
# Epoch(3/50): train_loss=4.2594e-02  valid_loss=4.1299e-02  lowest_loss=4.1299e-02
# Epoch(4/50): train_loss=4.1652e-02  valid_loss=4.0796e-02  lowest_loss=4.0796e-02
# Epoch(5/50): train_loss=4.1088e-02  valid_loss=4.0350e-02  lowest_loss=4.0350e-02
# Epoch(6/50): train_loss=4.1084e-02  valid_loss=4.0158e-02  lowest_loss=4.0158e-02
# Epoch(7/50): train_loss=4.0484e-02  valid_loss=4.0311e-02  lowest_loss=4.0158e-02
# Epoch(8/50): train_loss=4.0084e-02  valid_loss=3.9636e-02  lowest_loss=3.9636e-02
# Epoch(9/50): train_loss=3.9784e-02  valid_loss=3.8896e-02  lowest_loss=3.8896e-02
# Epoch(10/50): train_loss=3.9523e-02  valid_loss=3.9169e-02  lowest_loss=3.8896e-02
# Epoch(11/50): train_loss=3.9664e-02  valid_loss=3.9112e-02  lowest_loss=3.8896e-02
# Epoch(12/50): train_loss=3.9369e-02  valid_loss=3.8350e-02  lowest_loss=3.8350e-02
# Epoch(13/50): train_loss=3.8920e-02  valid_loss=3.8022e-02  lowest_loss=3.8022e-02
# Epoch(14/50): train_loss=3.9007e-02  valid_loss=3.8012e-02  lowest_loss=3.8012e-02
# Epoch(15/50): train_loss=3.8708e-02  valid_loss=3.8988e-02  lowest_loss=3.8012e-02
# Epoch(16/50): train_loss=3.8796e-02  valid_loss=3.8057e-02  lowest_loss=3.8012e-02
# Epoch(17/50): train_loss=3.8641e-02  valid_loss=3.8187e-02  lowest_loss=3.8012e-02
# Epoch(18/50): train_loss=3.8448e-02  valid_loss=3.7983e-02  lowest_loss=3.7983e-02
# Epoch(19/50): train_loss=3.8221e-02  valid_loss=3.7743e-02  lowest_loss=3.7743e-02
# Epoch(20/50): train_loss=3.8471e-02  valid_loss=3.7765e-02  lowest_loss=3.7743e-02
# Epoch(21/50): train_loss=3.8092e-02  valid_loss=3.7404e-02  lowest_loss=3.7404e-02
# Epoch(22/50): train_loss=3.7829e-02  valid_loss=3.7271e-02  lowest_loss=3.7271e-02
# Epoch(23/50): train_loss=3.7919e-02  valid_loss=3.7289e-02  lowest_loss=3.7271e-02
# Epoch(24/50): train_loss=3.8329e-02  valid_loss=3.8263e-02  lowest_loss=3.7271e-02
# Epoch(25/50): train_loss=3.8311e-02  valid_loss=3.7008e-02  lowest_loss=3.7008e-02
# Epoch(26/50): train_loss=3.7887e-02  valid_loss=3.6896e-02  lowest_loss=3.6896e-02
# Epoch(27/50): train_loss=3.8119e-02  valid_loss=3.8107e-02  lowest_loss=3.6896e-02
# Epoch(28/50): train_loss=3.7790e-02  valid_loss=3.6770e-02  lowest_loss=3.6770e-02
# Epoch(29/50): train_loss=3.8632e-02  valid_loss=3.7672e-02  lowest_loss=3.6770e-02
# Epoch(30/50): train_loss=3.8714e-02  valid_loss=3.8450e-02  lowest_loss=3.6770e-02
# Epoch(31/50): train_loss=3.8434e-02  valid_loss=3.7427e-02  lowest_loss=3.6770e-02
# Epoch(32/50): train_loss=3.7850e-02  valid_loss=3.7310e-02  lowest_loss=3.6770e-02
# Epoch(33/50): train_loss=3.7890e-02  valid_loss=3.7257e-02  lowest_loss=3.6770e-02
# Epoch(34/50): train_loss=3.7656e-02  valid_loss=3.6766e-02  lowest_loss=3.6766e-02
# Epoch(35/50): train_loss=3.7505e-02  valid_loss=3.7371e-02  lowest_loss=3.6766e-02
# Epoch(36/50): train_loss=3.7599e-02  valid_loss=3.6997e-02  lowest_loss=3.6766e-02
# Epoch(37/50): train_loss=3.7436e-02  valid_loss=3.6791e-02  lowest_loss=3.6766e-02
# Epoch(38/50): train_loss=3.7206e-02  valid_loss=3.6440e-02  lowest_loss=3.6440e-02
# Epoch(39/50): train_loss=3.7227e-02  valid_loss=3.6768e-02  lowest_loss=3.6440e-02
# Epoch(40/50): train_loss=3.7328e-02  valid_loss=3.6607e-02  lowest_loss=3.6440e-02
# Epoch(41/50): train_loss=3.7121e-02  valid_loss=3.6439e-02  lowest_loss=3.6439e-02
# Epoch(42/50): train_loss=3.7363e-02  valid_loss=3.6469e-02  lowest_loss=3.6439e-02
# Epoch(43/50): train_loss=3.6995e-02  valid_loss=3.6982e-02  lowest_loss=3.6439e-02
# Epoch(44/50): train_loss=3.7377e-02  valid_loss=3.6332e-02  lowest_loss=3.6332e-02
# Epoch(45/50): train_loss=3.7329e-02  valid_loss=3.6844e-02  lowest_loss=3.6332e-02
# Epoch(46/50): train_loss=3.7004e-02  valid_loss=3.6077e-02  lowest_loss=3.6077e-02
# Epoch(47/50): train_loss=3.7042e-02  valid_loss=3.6272e-02  lowest_loss=3.6077e-02
# Epoch(48/50): train_loss=3.7124e-02  valid_loss=3.6210e-02  lowest_loss=3.6077e-02
# Epoch(49/50): train_loss=3.6895e-02  valid_loss=3.6266e-02  lowest_loss=3.6077e-02
# Epoch(50/50): train_loss=3.6990e-02  valid_loss=3.6283e-02  lowest_loss=3.6077e-02

# %% [markdown]
# ## Test

# %%
with torch.no_grad():
    import random
    
    index = int(random.random() * test_x.size(0))
    
    recon = model(test_x[index].view(1, -1)).squeeze()
    
    show_image(test_x[index])
    show_image(recon)

# %% [markdown]
# ## Latent Space

# %%
if config.btl_size == 2:
    color_map = [
        "brown", "red", "orange", "yellow", "green",
        "blue", "navy", "purple", "gray", "black",
    ]
    
    plt.figure(figsize=(20, 10))
    with torch.no_grad():
        latents = model.encoder(test_x[:1000])
        
        for i in range(10):
            target_latents = latents[test_y[:1000] == i]
            target_y = test_y[:1000][test_y[:1000] == i]
            plt.scatter(target_latents[:, 0],
                       target_latents[:, 1],
                       marker="o",
                       color=color_map[i],
                       label=i)
        
        plt.legend()
        plt.grid(axis="both")
        plt.show()

# %%
if config.btl_size == 2:
    min_range, max_range = -2., 2.
    n = 20
    step = (max_range - min_range) / float(n)
    
    with torch.no_grad():
        lines = []
        
        for v1 in np.arange(min_range, max_range, step):
            z = torch.stack([
                torch.FloatTensor([v1] * n),
                torch.FloatTensor([v2 for v2 in np.arange(min_range,
                                                         max_range, step)]),
            ], dim=-1)
            
            line = torch.clamp(model.decoder(z).view(n, 28, 28), 0, 1)
            line = torch.cat([line[i] for i in range(n - 1, 0, -1)], dim=0)
            lines += [line]
            
        lines = torch.cat(lines, dim=-1)
        plt.figure(figsize=(20, 20))
        show_image(lines)
